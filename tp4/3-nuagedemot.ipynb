# %%
from collections import Counter
from wordcloud import WordCloud
import os
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from IPython.display import Image


import os
import yake

from collections import defaultdict
import os

import matplotlib.pyplot as plt
import numpy as np
import yake

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

from collections import Counter
from wordcloud import WordCloud
import os
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from IPython.display import Image

from collections import defaultdict
import sys
import spacy
from spacy.lang.fr.examples import sentences

import sys
from textblob import Blobber
from textblob_fr import PatternTagger, PatternAnalyzer

from datetime import datetime as dt
from SPARQLWrapper import SPARQLWrapper, JSON
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
word1 = 'culture '
value1 = 6556

with open('../data/nuage2.txt', 'w') as arquivo : 
    for word in words_nuage : 
        arquivo.write (word1 * value1)

# %%
word2 = 'théâtre '
value2 = 20919

with open('../data/nuage2.txt', 'a') as arquivo : 
    for word in words_nuage : 
        arquivo.write (word2 * value2)

# %%
word3 = 'cinéma '
value3 = 1676

with open('../data/nuage2.txt', 'a') as arquivo : 
    for word in words_nuage : 
        arquivo.write (word3 * value3)

# %%
word4 = 'museum '
value4 = 205

with open('../data/nuage2.txt', 'a') as arquivo : 
    for word in words_nuage : 
        arquivo.write (word4 * value4)

# %%
word5 = 'musée '
value5 = 7670

with open('../data/nuage2.txt', 'a') as arquivo : 
    for word in words_nuage : 
        arquivo.write (word5 * value5)

# %%
word6 = 'lieu culturel '
value6 = 4

with open('../data/nuage2.txt', 'a') as arquivo : 
    for word in words_nuage : 
        arquivo.write (word6 * value6)

# %%
word7 = 'centre culturel '
value7 = 344

with open('../data/nuage2.txt', 'a') as arquivo : 
    for word in words_nuage : 
        arquivo.write (word7 * value7)

# %%
word8 = 'patrimoine culturel '
value8 = 39

with open('../data/nuage2.txt', 'a') as arquivo : 
    for word in words_nuage : 
        arquivo.write (word8 * value8)

# %% [markdown]
# ## Cinémas

# %%
word9 = 'Pathé Palace '
value9 = 1
word10 = 'Théâtre des Variétés '
value10 = 1
word11 = 'Ciné Christine '
value11 = 1

with open('../data/nuage2.txt', 'a') as arquivo : 
    for word in words_nuage : 
        arquivo.write (word9 * value9)
        arquivo.write (word10 * value10) 
        arquivo.write (word11 * value11)

# %% [markdown]
# ## Centres Culturels

# %%
word12 = 'Les Brigittines '
value12 = 4
word13 = 'Beursschouwburg ' 
value13 = 32
word14 = 'Palais des Beaux-Arts '
value14 = 323
word15 = 'Kaaitheater '
value15 = 21

with open('../data/nuage2.txt', 'a') as arquivo : 
    for word in words_nuage : 
        arquivo.write (word12 * value12)
        arquivo.write (word13 * value13)
        arquivo.write (word14 * value14)
        arquivo.write (word15 * value15)

# %% [markdown]
# ## Musées

# %%
word16 = 'Musées royaux des Beaux-Arts '
value16 = 12
word17 = 'Aquarium ' 
value17 = 17
word18 = 'Observatoire royal de Belgique '
value18 = 3
word19 = 'Cinémathèque '
value19 = 1
word20 = 'Musée de l’Industrie '
value20 = 23
word21 = 'Musée instrumental '
value21 = 2
word22 = 'Musée de la Porte_de_Hal '
value22 = 2
word23 = 'Musée du Cinquantenaire '
value23 = 11
word24 = 'Musées royaux d’Art et d’Histoire '
value24 = 9

with open('../data/nuage2.txt', 'a') as arquivo : 
    for word in words_nuage : 
        arquivo.write (word16 * value16)
        arquivo.write (word17 * value17)
        arquivo.write (word18 * value18)
        arquivo.write (word19 * value19)
        arquivo.write (word20 * value20)
        arquivo.write (word21 * value21)
        arquivo.write (word22 * value22)
        arquivo.write (word23 * value23)
        arquivo.write (word24 * value24)

# %% [markdown]
# ## Théâtres

# %%
word25 = 'Fantaisies-Parisiennes '
value25 = 3
word26 = 'Théâtre du Vaudeville ' 
value26 = 15
word27 = 'Théâtre royal du Parc '
value27 = 19
word28 = 'Cercle Gaulois '
value28 = 12
word29 = 'La Samaritaine '
value29 = 3
word30 = 'Théâtre royal flamand de Bruxelles '
value30 = 19
word31 = 'Concert Noble '
value31 = 25
word32 = 'Salle Patria '
value32 = 7


with open('../data/nuage2.txt', 'a') as arquivo : 
    for word in words_nuage : 
        arquivo.write (word25 * value25)
        arquivo.write (word26 * value26)
        arquivo.write (word27 * value27)
        arquivo.write (word28 * value28)
        arquivo.write (word29 * value29)
        arquivo.write (word30 * value30)
        arquivo.write (word31 * value31)
        arquivo.write (word32 * value32)

# %%
# Récupération du contenu du fichier
path = "../data/nuage2.txt"
limit = 10**8

with open(path) as f:
    text = f.read()[:limit]

# %%
temp_path = '../data/tmp'
if not os.path.exists(temp_path):
    os.mkdir(temp_path)
    
cloud = WordCloud(width=600, height=300, background_color='white').generate(text)
cloud.to_file(os.path.join(temp_path, f"teste.png"))
Image(filename=os.path.join(temp_path, f"teste.png"))

# %%
temp_path = '../data/tmp'
if not os.path.exists(temp_path):
    os.mkdir(temp_path)
    
# Création d'une liste de mots à ignorer
ignored = set( ['des', "l'", 'du', 'de', 'l', 'les'])

ignored
    
cloud = WordCloud(width=400, height=200, background_color='white').generate(text)
cloud.to_file(os.path.join(temp_path, f"teste1.png"))
Image(filename=os.path.join(temp_path, f"teste1.png"))

# %%
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");

# %%
# Generate word cloud
wordcloud = WordCloud(min_font_size = 12,  width= 800, height = 400, random_state=1, background_color='salmon', 
                      colormap='Pastel2', collocations=False).generate(text)
# Plot
plot_cloud(wordcloud)

# %%
wordcloud = WordCloud(width = 1000, height = 500, random_state=1, background_color='black', 
                      colormap='Set2', collocations=False).generate(text)
# Plot
plot_cloud(wordcloud)

# %%
# Save image
wordcloud.to_file("wordcloud.png")
